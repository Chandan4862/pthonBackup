# %%
import pandas as pd
import numpy as np


training= pd.read_csv('training.csv')
training.head()
# Out:
#   class  b1  b2  b3   b4  b5   b6   b7  b8  b9  ...  pred_minus_obs_H_b9  \
# 0    d   39  36  57   91  59  101   93  27  60  ...                -2.36
# 1    h   84  30  57  112  51   98   92  26  62  ...                -2.26
# 2    s   53  25  49   99  51   93   84  26  58  ...                -1.46
# 3    s   59  26  49  103  47   92   82  25  56  ...                 2.68
# 4    d   57  49  66  103  64  106  114  28  59  ...                -2.94
#
#    pred_minus_obs_S_b1  pred_minus_obs_S_b2  pred_minus_obs_S_b3  \
# 0               -18.41                -1.88                -6.43
# 1               -16.27                -1.95                -6.25
# 2               -15.92                -1.79                -4.64
# 3               -13.77                -2.53                -6.34
# 4               -21.74                -1.64                -4.62
#
#    pred_minus_obs_S_b4  pred_minus_obs_S_b5  pred_minus_obs_S_b6  \
# 0               -21.03                -1.60                -6.18
# ...

# %%
cols = training.columns
for col in cols:
    if col != 'class':
        xcol.append(col)

# %%
x = training[xcol].values
y = training[['class']].values
y
# Out:
# array([['d '],
#        ['h '],
#        ['s '],
#        ['s '],
#        ['d '],
#        ['h '],
#        ['s '],
#        ['d '],
#        ['s '],
#        ['o '],
#        ['d '],
#        ['o '],
#        ['o '],
#        ['d '],
#        ['s '],
#        ['o '],
#        ['o '],
#        ['d '],
#        ['s '],
#        ['h '],
#        ['o '],
#        ['d '],
#        ['s '],
#        ['h '],
#        ['d '],
#        ['h '],
#        ['o '],
#        ['d '],
#        ['d '],
#        ['d '],
#        ['d '],
#        ['s '],
#        ['o '],
#        ['s '],
#        ['d '],
#        ['d '],
#        ['d '],
#        ['h '],
#        ['o '],
#        ['d '],
#        ['d '],
#        ['d '],
#        ['s '],
#        ['s '],
#        ['h '],
#        ['d '],
#        ['d '],
#        ['o '],
#        ['d '],
#        ['s '],
#        ['d '],
#        ['s '],
#        ['s '],
#        ['h '],
#        ['h '],
#        ['s '],
#        ['o '],
#        ['d '],
# ...

# %%
test = pd.read_csv('testing.csv')
x_test=test[xcol].values
y_test=test[['class']].values

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

encoder.fit(y)
y=encoder.transform(y)
y_test = encoder.transform(y_test)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf = clf.fit(x, y)
clf.score(x_test,encoder.transform(y_test))
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test,y_pred)
# Out:
# array([[ 76,   0,  15,  14],
#        [  0,  29,   0,   9],
#        [ 10,   1,  35,   0],
#        [  7,  12,   0, 117]], dtype=int64)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(x)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf = clf.fit(pca.transform(x), y)
clf.score(pca.transform(x_test),encoder.transform(y_test))
y_pred=clf.predict(pca.transform(x_test))

from sklearn.metrics import confusion_matrix

confusion_matrix(y_test,y_pred)
# Out:
# array([[ 75,   0,  13,  17],
#        [  1,  27,   1,   9],
#        [ 12,   0,  33,   1],
#        [ 16,  13,   2, 105]], dtype=int64)
